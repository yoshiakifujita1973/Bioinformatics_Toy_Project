# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data
df_s = pd.read_csv('ProjectSummarySingle_csv.csv')
df_p = pd.read_csv('ProjectSummaryPaired_csv.csv')

df_p
# Out:
#        Filename     End  ERRRate       N  Read       avg_num     avg_len  \
# 0   myasmb_p001  Paired     0.01    5000   100    544.333333  217.300000
# 1   myasmb_p002  Paired     0.01    5000   200    524.666667  222.933333
# 2   myasmb_p003  Paired     0.01    5000   300    502.333333  233.200000
# 3   myasmb_p004  Paired     0.01    5000   400    530.666667  221.300000
# 4   myasmb_p005  Paired     0.01    5000   500    556.000000  212.666667
# ..          ...     ...      ...     ...   ...           ...         ...
# 65  myasmb_p066  Paired     0.01  100000   600  31262.666670   35.266667
# 66  myasmb_p067  Paired     0.01  100000   700  30825.000000   35.333333
# 67  myasmb_p068  Paired     0.01  100000   800  31552.666670   35.266667
# 68  myasmb_p069  Paired     0.01  100000   900  31099.000000   35.333333
# 69  myasmb_p070  Paired     0.01  100000  1000  31433.333330   35.300000
#
#     max_len   avg_prd
# 0      3527  1.000000
# 1      2961  1.333333
# ...

# %%
# Split data into each condistion
df_p_Err001_N5000 = df_p[(df_p['ERRRate']==0.0100)&(df_p['N']==5000)]
df_p_Err001_N10000 = df_p[(df_p['ERRRate']==0.0100)&(df_p['N']==10000)]
df_p_Err001_N100000 = df_p[(df_p['ERRRate']==0.0100)&(df_p['N']==100000)]
df_p_Err0001_N5000 = df_p[(df_p['ERRRate']==0.0010)&(df_p['N']==5000)]
df_p_Err0001_N10000 = df_p[(df_p['ERRRate']==0.0010)&(df_p['N']==10000)]
df_p_Err00001_N5000 = df_p[(df_p['ERRRate']==0.0001)&(df_p['N']==5000)]
df_p_Err00001_N10000 = df_p[(df_p['ERRRate']==0.0001)&(df_p['N']==10000)]

df_s_Err001_N5000 = df_s[(df_s['ERRRate']==0.0100)&(df_s['N']==5000)]
df_s_Err001_N10000 = df_s[(df_s['ERRRate']==0.0100)&(df_s['N']==10000)]
df_s_Err001_N100000 = df_s[(df_s['ERRRate']==0.0100)&(df_s['N']==100000)]
df_s_Err0001_N5000 = df_s[(df_s['ERRRate']==0.0010)&(df_s['N']==5000)]
df_s_Err0001_N10000 = df_s[(df_s['ERRRate']==0.0010)&(df_s['N']==10000)]
df_s_Err00001_N5000 = df_s[(df_s['ERRRate']==0.0001)&(df_s['N']==5000)]
df_s_Err00001_N10000 = df_s[(df_s['ERRRate']==0.0001)&(df_s['N']==10000)]

# %%
# Influence of Error rate

import matplotlib.pyplot as plt
fig,a =  plt.subplots(2,2, figsize=(10,6))


a[0][0].scatter(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_len, color='green')
a[0][0].scatter(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_len, color='green', alpha=0.5)
a[0][0].scatter(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_len, color='green', alpha=0.3)
a[0][0].plot(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_len, color='green')
a[0][0].plot(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_len, color='green', alpha=0.5)
a[0][0].plot(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_len, color='green', alpha=0.3)
a[0][0].set_xticks([])
a[0][0].set_yticks((200, 400, 600, 800, 1000))
a[0][0].set_ylabel('average length')
a[0][0].set_title('N=5000, Single-End')

a[0][1].scatter(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_len, color='green')
a[0][1].scatter(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[0][1].scatter(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_len, color='green', alpha=0.3)
a[0][1].plot(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_len, color='green')
a[0][1].plot(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[0][1].plot(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_len, color='green', alpha=0.3)
a[0][1].set_yticks((200, 400, 600, 800, 1000))
a[0][1].set_xticks([])
a[0][1].set_title('N=10000, Single-End')

a[1][0].scatter(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_len, color='green')
a[1][0].scatter(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_len, color='green', alpha=0.5)
a[1][0].scatter(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_len, color='green', alpha=0.3)
a[1][0].plot(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_len, color='green')
a[1][0].plot(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_len, color='green', alpha=0.5)
a[1][0].plot(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_len, color='green', alpha=0.3)
a[1][0].set_yticks((200, 400, 600, 800, 1000))
a[1][0].set_ylabel('average length')
a[1][0].set_xlabel('Length of Reads')
a[1][0].set_title('N=5000, Paired-End')

a[1][1].scatter(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_len, color='green')
a[1][1].scatter(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][1].scatter(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_len, color='green', alpha=0.3)
a[1][1].plot(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_len, color='green')
a[1][1].plot(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][1].plot(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_len, color='green', alpha=0.3)
a[1][1].set_yticks((200, 400, 600, 800, 1000))
a[1][1].set_xlabel('Length of Reads')
a[1][1].set_title('N=10000, Paired-End')
plt.figure(figsize=(10,14))

plt.show()

# %%
# Influence of Sequence of Depth

fig,a =  plt.subplots(3,2, figsize=(10,6))

a[0][0].scatter(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_len, color='green')
a[0][0].scatter(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_len, color='green', alpha=0.5)
a[0][0].scatter(df_s_Err001_N100000.Read, df_s_Err001_N100000.avg_len, color='green', alpha=0.3)
a[0][0].plot(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_len, color='green')
a[0][0].plot(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_len, color='green', alpha=0.5)
a[0][0].plot(df_s_Err001_N100000.Read, df_s_Err001_N100000.avg_len, color='green', alpha=0.3)
a[0][0].set_xticks([])
a[0][0].set_yticks((200, 400, 600))
a[0][0].set_ylabel('average length')
a[0][0].set_title('Err Rate=0.01, Single-End')

a[0][1].scatter(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_len, color='green')
a[0][1].scatter(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_len, color='green', alpha=0.5)
a[0][1].scatter(df_p_Err001_N100000.Read, df_p_Err001_N100000.avg_len, color='green', alpha=0.3)
a[0][1].plot(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_len, color='green')
a[0][1].plot(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_len, color='green', alpha=0.5)
a[0][1].plot(df_p_Err001_N100000.Read, df_p_Err001_N100000.avg_len, color='green', alpha=0.3)
a[0][1].set_xticks([])
a[0][1].set_yticks((200, 400, 600))
a[0][1].set_title('Err Rate=0.01, Paired-End')

a[1][0].scatter(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_len, color='green')
a[1][0].scatter(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][0].plot(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_len, color='green')
a[1][0].plot(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][0].set_xticks([])
a[1][0].set_yticks((600, 800, 1000))
a[1][0].set_ylabel('average length')
a[1][0].set_title('Err Rate=0.001, Single-End')


a[1][1].scatter(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_len, color='green')
a[1][1].scatter(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][1].plot(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_len, color='green')
a[1][1].plot(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][1].set_xticks([])
a[1][1].set_yticks((600, 800, 1000))
a[1][1].set_title('Err Rate=0.001, Paired-End')

a[2][0].scatter(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_len, color='green')
a[2][0].scatter(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_len, color='green', alpha=0.5)
a[2][0].plot(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_len, color='green')
a[2][0].plot(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_len, color='green', alpha=0.5)
a[2][0].set_yticks((600, 800, 1000))
a[2][0].set_ylabel('average length')
a[2][0].set_xlabel('Length of Reads')
a[2][0].set_title('Err Rate=0.0001, Single-End')


a[2][1].scatter(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_len, color='green')
a[2][1].scatter(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_len, color='green', alpha=0.5)
a[2][1].plot(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_len, color='green')
a[2][1].plot(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_len, color='green', alpha=0.5)
a[2][1].set_yticks((600, 800, 1000))
a[2][1].set_xlabel('Length of Reads')
a[2][1].set_title('Err Rate=0.0001,  Paired-End')
plt.figure(figsize=(8,16))

#plt.legend(loc='upper center')
plt.show()

# %%
# Influence of Sequence of Depth

fig,a =  plt.subplots(2,2, figsize=(10,4))

a[0][0].scatter(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_num, color='green')
a[0][0].scatter(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_num, color='green', alpha=0.5)
a[0][0].scatter(df_s_Err001_N100000.Read, df_s_Err001_N100000.avg_num, color='green', alpha=0.3)
a[0][0].plot(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_num, color='green')
a[0][0].plot(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_num, color='green', alpha=0.5)
a[0][0].plot(df_s_Err001_N100000.Read, df_s_Err001_N100000.avg_num, color='green', alpha=0.3)
a[0][0].set_xticks([])
a[0][0].set_yticks((0, 30000))
a[0][0].set_ylabel('average number')
a[0][0].set_title('Err Rate=0.01, Single-End')

a[0][1].scatter(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_num, color='green')
a[0][1].scatter(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_num, color='green', alpha=0.5)
a[0][1].scatter(df_p_Err001_N100000.Read, df_p_Err001_N100000.avg_num, color='green', alpha=0.3)
a[0][1].plot(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_num, color='green')
a[0][1].plot(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_num, color='green', alpha=0.5)
a[0][1].plot(df_p_Err001_N100000.Read, df_p_Err001_N100000.avg_num, color='green', alpha=0.3)
a[0][1].set_xticks([])
a[0][1].set_yticks((0, 30000))
a[0][1].set_title('Err Rate=0.01, Paired-End')

a[1][0].scatter(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_num, color='green')
a[1][0].scatter(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_num, color='green', alpha=0.5)
a[1][0].plot(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_num, color='green')
a[1][0].plot(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_num, color='green', alpha=0.5)
a[1][0].set_xticks([])
a[1][0].set_yticks((300, 1500))
a[1][0].set_ylabel('average number')
a[1][0].set_title('Err Rate=0.01, Single-End')

a[1][1].scatter(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_num, color='green')
a[1][1].scatter(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_num, color='green', alpha=0.5)
a[1][1].plot(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_num, color='green')
a[1][1].plot(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_num, color='green', alpha=0.5)
a[1][1].set_xticks([])
a[1][1].set_yticks((300, 1500))
a[1][1].set_title('Err Rate=0.01, Paired-End')

#plt.legend(loc='upper center')
plt.show()

# %%
# Influence of Sequence of Depth

fig,a =  plt.subplots(2,2, figsize=(10,4))


a[0][0].scatter(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_num, color='green')
a[0][0].scatter(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_num, color='green', alpha=0.5)
a[0][0].plot(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_num, color='green')
a[0][0].plot(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_num, color='green', alpha=0.5)
a[0][0].set_yticks((100, 200))
a[0][0].set_xticks([])
a[0][0].set_ylabel('average number')
a[0][0].set_title('Err Rate=0.0001, Single-End')

a[0][1].scatter(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_num, color='green')
a[0][1].scatter(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_num, color='green', alpha=0.5)
a[0][1].plot(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_num, color='green')
a[0][1].plot(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_num, color='green', alpha=0.5)
a[0][1].set_yticks((100, 200))
a[0][1].set_xticks([])
a[0][1].set_title('Err Rate=0.0001,  Paired-End')

a[1][0].scatter(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_num, color='green')
a[1][0].scatter(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_num, color='green', alpha=0.5)
a[1][0].plot(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_num, color='green')
a[1][0].plot(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_num, color='green', alpha=0.5)
a[1][0].set_yticks((100, 200))
a[1][0].set_ylabel('average number')
a[1][0].set_xlabel('Length of Reads')
a[1][0].set_title('Err Rate=0.0001, Single-End')

a[1][1].scatter(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_num, color='green')
a[1][1].scatter(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_num, color='green', alpha=0.5)
a[1][1].plot(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_num, color='green')
a[1][1].plot(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_num, color='green', alpha=0.5)
a[1][1].set_yticks((100, 200))
a[1][1].set_xlabel('Length of Reads')
a[1][1].set_title('Err Rate=0.0001,  Paired-End')
plt.figure(figsize=(8,8))

#plt.legend(loc='upper center')
plt.show()

# %%
# Influence of Single-end vs Paired-end

fig,a =  plt.subplots(3,2, figsize=(10,6))

a[0][0].scatter(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_len, color='green')
a[0][0].scatter(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_len, color='green', alpha=0.5)
a[0][0].plot(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_len, color='green')
a[0][0].plot(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_len, color='green', alpha=0.5)
a[0][0].set_xticks([])
a[0][0].set_yticks((100, 500))
a[0][0].set_ylabel('average length')
a[0][0].set_title('Err Rate=0.01, N=5000')

a[0][1].scatter(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_len, color='green')
a[0][1].scatter(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_len, color='green', alpha=0.5)
a[0][1].plot(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_len, color='green')
a[0][1].plot(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_len, color='green', alpha=0.5)
a[0][1].set_xticks([])
a[0][1].set_xticks([])
a[0][1].set_yticks((100, 500))
a[0][1].set_title('Err Rate=0.01, N=10000')

a[1][0].scatter(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_len, color='green')
a[1][0].scatter(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_len, color='green', alpha=0.5)
a[1][0].plot(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_len, color='green')
a[1][0].plot(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_len, color='green', alpha=0.5)
a[1][0].set_xticks([])
a[1][0].set_yticks((500, 1000))
a[1][0].set_ylabel('average length')
a[1][0].set_title('Err Rate=0.001, N=5000')


a[1][1].scatter(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_len, color='green')
a[1][1].scatter(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][1].plot(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_len, color='green')
a[1][1].plot(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_len, color='green', alpha=0.5)
a[1][1].set_xticks([])
a[1][1].set_yticks((500, 1000))
a[1][1].set_title('Err Rate=0.001, N=10000')

a[2][0].scatter(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_len, color='green')
a[2][0].scatter(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_len, color='green', alpha=0.5)
a[2][0].plot(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_len, color='green')
a[2][0].plot(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_len, color='green', alpha=0.5)
a[2][0].set_yticks((500, 1000))
a[2][0].set_ylabel('average length')
a[2][0].set_xlabel('Length of Reads')
a[2][0].set_title('Err Rate=0.0001, N=5000')


a[2][1].scatter(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_len, color='green')
a[2][1].scatter(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_len, color='green', alpha=0.5)
a[2][1].plot(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_len, color='green')
a[2][1].plot(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_len, color='green', alpha=0.5)
a[2][1].set_yticks((500, 1000))
a[2][1].set_xlabel('Length of Reads')
a[2][1].set_title('Err Rate=0.0001,  N=10000')
plt.figure(figsize=(8,16))

#plt.legend(loc='upper center')
plt.show()

# %%
# Influence of Error rate

import matplotlib.pyplot as plt
fig,a =  plt.subplots(2,2, figsize=(10,6))


a[0][0].scatter(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_prd, color='green')
a[0][0].scatter(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_prd, color='green', alpha=0.5)
a[0][0].scatter(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_prd, color='green', alpha=0.3)
a[0][0].plot(df_s_Err001_N5000.Read, df_s_Err001_N5000.avg_prd, color='green')
a[0][0].plot(df_s_Err0001_N5000.Read, df_s_Err0001_N5000.avg_prd, color='green', alpha=0.5)
a[0][0].plot(df_s_Err00001_N5000.Read, df_s_Err00001_N5000.avg_prd, color='green', alpha=0.3)
a[0][0].set_xticks([])
a[0][0].set_yticks((2, 4, 6, 8, 10))
a[0][0].set_ylabel('number of predictions')
a[0][0].set_title('N=5000, Single-End')

a[0][1].scatter(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_prd, color='green')
a[0][1].scatter(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_prd, color='green', alpha=0.5)
a[0][1].scatter(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_prd, color='green', alpha=0.3)
a[0][1].plot(df_s_Err001_N10000.Read, df_s_Err001_N10000.avg_prd, color='green')
a[0][1].plot(df_s_Err0001_N10000.Read, df_s_Err0001_N10000.avg_prd, color='green', alpha=0.5)
a[0][1].plot(df_s_Err00001_N10000.Read, df_s_Err00001_N10000.avg_prd, color='green', alpha=0.3)
a[0][1].set_yticks((2, 4, 6, 8, 10))
a[0][1].set_xticks([])
a[0][1].set_title('N=10000, Single-End')

a[1][0].scatter(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_prd, color='green')
a[1][0].scatter(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_prd, color='green', alpha=0.5)
a[1][0].scatter(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_prd, color='green', alpha=0.3)
a[1][0].plot(df_p_Err001_N5000.Read, df_p_Err001_N5000.avg_prd, color='green')
a[1][0].plot(df_p_Err0001_N5000.Read, df_p_Err0001_N5000.avg_prd, color='green', alpha=0.5)
a[1][0].plot(df_p_Err00001_N5000.Read, df_p_Err00001_N5000.avg_prd, color='green', alpha=0.3)
a[1][0].set_yticks((2, 4, 6, 8, 10))
a[1][0].set_ylabel('number of predictions')
a[1][0].set_xlabel('Length of Reads')
a[1][0].set_title('N=5000, Paired-End')

a[1][1].scatter(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_prd, color='green')
a[1][1].scatter(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_prd, color='green', alpha=0.5)
a[1][1].scatter(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_prd, color='green', alpha=0.3)
a[1][1].plot(df_p_Err001_N10000.Read, df_p_Err001_N10000.avg_prd, color='green')
a[1][1].plot(df_p_Err0001_N10000.Read, df_p_Err0001_N10000.avg_prd, color='green', alpha=0.5)
a[1][1].plot(df_p_Err00001_N10000.Read, df_p_Err00001_N10000.avg_prd, color='green', alpha=0.3)
a[1][1].set_yticks((2, 4, 6, 8, 10))
a[1][1].set_xlabel('Length of Reads')
a[1][1].set_title('N=10000, Paired-End')
plt.figure(figsize=(10,14))

plt.show()

# %%
# Calculation of probability of prediction (num of predictions / num of generated cotings)
df_s_Err001_N5000_p_prd = df_s_Err001_N5000.avg_prd / df_s_Err001_N5000.avg_num
df_s_Err0001_N5000_p_prd = df_s_Err0001_N5000.avg_prd / df_s_Err0001_N5000.avg_num
df_s_Err00001_N5000_p_prd = df_s_Err00001_N5000.avg_prd / df_s_Err00001_N5000.avg_num

df_s_Err001_N10000_p_prd = df_s_Err001_N10000.avg_prd / df_s_Err001_N10000.avg_num
df_s_Err0001_N10000_p_prd = df_s_Err0001_N10000.avg_prd / df_s_Err0001_N10000.avg_num
df_s_Err00001_N10000_p_prd = df_s_Err00001_N10000.avg_prd / df_s_Err00001_N10000.avg_num

df_p_Err001_N5000_p_prd = df_p_Err001_N5000.avg_prd / df_p_Err001_N5000.avg_num
df_p_Err0001_N5000_p_prd = df_p_Err0001_N5000.avg_prd / df_p_Err0001_N5000.avg_num
df_p_Err00001_N5000_p_prd = df_p_Err00001_N5000.avg_prd / df_p_Err00001_N5000.avg_num

df_p_Err001_N10000_p_prd = df_p_Err001_N10000.avg_prd / df_p_Err001_N10000.avg_num
df_p_Err0001_N10000_p_prd = df_p_Err0001_N10000.avg_prd / df_p_Err0001_N10000.avg_num
df_p_Err00001_N10000_p_prd = df_p_Err00001_N10000.avg_prd / df_p_Err00001_N10000.avg_num

# %%
# Influence of Error rate

import matplotlib.pyplot as plt
fig,a =  plt.subplots(2,2, figsize=(10,6))


a[0][0].scatter(df_s_Err001_N5000.Read, df_s_Err001_N5000_p_prd, color='green')
a[0][0].scatter(df_s_Err0001_N5000.Read, df_s_Err0001_N5000_p_prd, color='green', alpha=0.5)
a[0][0].scatter(df_s_Err00001_N5000.Read, df_s_Err00001_N5000_p_prd, color='green', alpha=0.3)
a[0][0].plot(df_s_Err001_N5000.Read, df_s_Err001_N5000_p_prd, color='green')
a[0][0].plot(df_s_Err0001_N5000.Read, df_s_Err0001_N5000_p_prd, color='green', alpha=0.5)
a[0][0].plot(df_s_Err00001_N5000.Read, df_s_Err00001_N5000_p_prd, color='green', alpha=0.3)
a[0][0].set_xticks([])
#a[0][0].set_yticks((2, 4, 6, 8, 10))
a[0][0].set_ylabel('prediction probability')
a[0][0].set_title('N=5000, Single-End')

a[0][1].scatter(df_s_Err001_N10000.Read, df_s_Err001_N10000_p_prd, color='green')
a[0][1].scatter(df_s_Err0001_N10000.Read, df_s_Err0001_N10000_p_prd, color='green', alpha=0.5)
a[0][1].scatter(df_s_Err00001_N10000.Read, df_s_Err00001_N10000_p_prd, color='green', alpha=0.3)
a[0][1].plot(df_s_Err001_N10000.Read, df_s_Err001_N10000_p_prd, color='green')
a[0][1].plot(df_s_Err0001_N10000.Read, df_s_Err0001_N10000_p_prd, color='green', alpha=0.5)
a[0][1].plot(df_s_Err00001_N10000.Read, df_s_Err00001_N10000_p_prd, color='green', alpha=0.3)
#a[0][1].set_yticks((2, 4, 6, 8, 10))
a[0][1].set_xticks([])
a[0][1].set_title('N=10000, Single-End')

a[1][0].scatter(df_p_Err001_N5000.Read, df_p_Err001_N5000_p_prd, color='green')
a[1][0].scatter(df_p_Err0001_N5000.Read, df_p_Err0001_N5000_p_prd, color='green', alpha=0.5)
a[1][0].scatter(df_p_Err00001_N5000.Read, df_p_Err00001_N5000_p_prd, color='green', alpha=0.3)
a[1][0].plot(df_p_Err001_N5000.Read, df_p_Err001_N5000_p_prd, color='green')
a[1][0].plot(df_p_Err0001_N5000.Read, df_p_Err0001_N5000_p_prd, color='green', alpha=0.5)
a[1][0].plot(df_p_Err00001_N5000.Read, df_p_Err00001_N5000_p_prd, color='green', alpha=0.3)
#a[1][0].set_yticks((2, 4, 6, 8, 10))
a[1][0].set_ylabel('prediction probability')
a[1][0].set_xlabel('Length of Reads')
a[1][0].set_title('N=5000, Paired-End')

a[1][1].scatter(df_p_Err001_N10000.Read, df_p_Err001_N10000_p_prd, color='green')
a[1][1].scatter(df_p_Err0001_N10000.Read, df_p_Err0001_N10000_p_prd, color='green', alpha=0.5)
a[1][1].scatter(df_p_Err00001_N10000.Read, df_p_Err00001_N10000_p_prd, color='green', alpha=0.3)
a[1][1].plot(df_p_Err001_N10000.Read, df_p_Err001_N10000_p_prd, color='green')
a[1][1].plot(df_p_Err0001_N10000.Read, df_p_Err0001_N10000_p_prd, color='green', alpha=0.5)
a[1][1].plot(df_p_Err00001_N10000.Read, df_p_Err00001_N10000_p_prd, color='green', alpha=0.3)
#a[1][1].set_yticks((2, 4, 6, 8, 10))
a[1][1].set_xlabel('Length of Reads')
a[1][1].set_title('N=10000, Paired-End')
plt.figure(figsize=(10,14))

plt.show()
